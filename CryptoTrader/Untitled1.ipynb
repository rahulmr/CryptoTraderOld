# %%
from CryptoScraper import cryptoDownloader, getAllData
import pandas as pd
from data_utils import BasicFunctions, PriceFunctions, addData
# %load_ext autoreload
# %autoreload 2

# %%
dr = getAllData(cacheOnly=True, how='union')

# %%
coinDf = dr.data()
# Out:
# Getting BTC data
# Getting DASH data
# Getting DOGE data
# Getting ETH data
# Getting LTC data
# Getting STR data
# Getting XMR data
# Getting XRP data

# %%
coinDf['BTC'].sample(5)
# Out:
#              Date      Open    Close     High      Low       Volume
# 36993  1497949200  2592.500  2577.80  2592.50  2568.20   385.355284
# 35827  1493751600  1534.100  1545.60  1554.10  1473.00  2965.053838
# 4107   1379559600   126.970   127.63   127.63   126.97     8.550956
# 18624  1431820800   235.850   236.12   236.26   235.72   168.562169
# 9570   1399226400   434.348   435.05   435.50   434.00    42.097325

# %%
pf = PriceFunctions()

# %%
dataDf = pf.add_yColumns(coinDf)

# %%
dataDf['LTC'].sample(5)
# Out:
#                 Open     Close      High       Low     Volume  \
# Date
# 1453028400  0.007930  0.007949  0.007949  0.007920   0.576302
# 1465218000  0.008420  0.008499  0.008499  0.008420   3.380321
# 1463947200  0.008872  0.008862  0.008915  0.008856  19.653222
# 1453867200  0.008030  0.008002  0.008031  0.007900   6.137740
# 1455094800  0.008050  0.008070  0.008093  0.008015   8.833246
#
#             Percentage Change  Classification
# Date
# 1453028400           0.007246             0.0
# 1465218000           0.014159             0.0
# 1463947200           0.014329             1.0
# 1453867200           0.017405             1.0
# 1455094800           0.008750             0.0

# %%
ad = addData(dataDf)

# %%
dataGo = ad.data_adder('google')
# Out:
# Adding google data for BTC
# Adding google data for DASH
# Adding google data for DOGE
# Adding google data for ETH
# Adding google data for LTC
# Adding google data for STR
# Adding google data for XMR
# Adding google data for XRP

# %%
dataGo['XMR'].sample(5)
# Out:
#                 Open     Close      High       Low     Volume  \
# Date
# 1422374400  0.001296  0.001211  0.001296  0.001210  10.002659
# 1411002000  0.003800  0.003730  0.003800  0.003730   2.983159
# 1479697200  0.009118  0.009168  0.009200  0.009095  30.220913
# 1446037200  0.001408  0.001455  0.001474  0.001388   6.620120
# 1462716000  0.001870  0.001884  0.001920  0.001868  21.041929
#
#             Percentage Change  Classification  Google Trend
# Date
# 1422374400           0.057790             1.0           1.0
# 1411002000           0.021926             0.0           1.0
# 1479697200           0.149511             1.0           1.0
# 1446037200           0.037756             0.0           1.0
# 1462716000           0.009838             0.0           1.0

# %%
dataWi = ad.data_adder('wikipedia')
# Out:
# Adding wikipedia data for BTC
# Adding wikipedia data for DASH
# Adding wikipedia data for DOGE
# Adding wikipedia data for ETH
# Adding wikipedia data for LTC
# Adding wikipedia data for STR
# Adding wikipedia data for XMR
# Adding wikipedia data for XRP

# %%
dataWi['LTC'].sample(5)
# Out:
#                 Open     Close      High       Low      Volume  \
# Date
# 1443675600  0.012618  0.012522  0.012618  0.012522    0.406629
# 1431745200  0.006126  0.006146  0.006146  0.006126    0.033858
# 1391230800  0.028500  0.028500  0.028500  0.028500    0.000000
# 1499014800  0.016249  0.016130  0.016290  0.015100  856.582153
# 1441771200  0.012520  0.012520  0.012520  0.012520    0.000233
#
#             Percentage Change  Classification  Google Trend  Wikipedia View
# Date
# 1443675600           0.011029             1.0           0.0           194.0
# 1431745200           0.004706             0.0           0.0           194.0
# 1391230800           0.010638             0.0           1.0             NaN
# 1499014800           0.120236             1.0          25.0          3487.0
# 1441771200           0.010520             0.0           0.0           194.0

# %%
blockchainAd = ad.data_adder('blockchain')
# Out:
# Adding blockchain data for BTC

# %%
blockchainAd['BTC'].sample(5)
# Out:
#                Open    Close     High      Low       Volume  \
# Date
# 1523696400  8110.80  8035.20  8122.00  7953.00  3132.269496
# 1481634000   779.43   778.42   779.65   778.42    33.371885
# 1404493200   635.23   636.99   636.99   635.20    42.172345
# 1453147200   386.80   386.64   386.98   386.49   291.948437
# 1426903200   261.06   260.93   261.81   260.27   323.902361
#
#             Percentage Change  Classification  Google Trend  Wikipedia View  \
# Date
# 1523696400           0.010065             1.0          40.0         12176.0
# 1481634000           0.001782             1.0           4.0         10295.0
# 1404493200           0.006860             0.0           2.0             NaN
# 1453147200           0.017045             0.0           4.0         11821.0
# 1426903200           0.003345             0.0           2.0          7240.0
#
#               difficulty  cost-per-transaction-percent  cost-per-transaction  \
# Date
# 1523696400  3.796188e+12                      2.685256             86.216072
# 1481634000  2.867658e+11                      0.739411              5.907805
# 1404493200  1.681846e+10                      4.848067             41.167589
# 1453147200  1.133543e+11                      1.652174              6.929569
# 1426903200  4.742755e+10                      2.637325              9.211331
#
#             estimated-transaction-volume-usd  estimated-transaction-volume  \
# Date
# 1523696400                      7.260331e+08                  89364.302045
# 1481634000                      1.766416e+08                 225273.529975
# 1404493200                      3.891748e+07                  62246.571429
# 1453147200                      1.044368e+08                 265122.285714
# 1426903200                      4.206940e+07                 167344.571429
#
#                hash-rate  miners-revenue  n-transactions  output-volume  \
# Date
# 1523696400  2.614693e+07    1.376253e+07        161843.0   9.185395e+05
# 1481634000  2.223812e+06    1.520295e+06        268662.0   1.453338e+06
# 1404493200  1.337680e+05    2.548315e+06         61901.0   3.759950e+05
# 1453147200  8.395960e+05    1.425655e+06        205735.0   1.940316e+07
# 1426903200  3.371420e+05    9.253519e+05        100458.0   7.961102e+05
#
#             transaction-fees
# Date
# 1523696400         23.759396
# 1481634000         93.126401
# 1404493200         10.588249
# 1453147200         40.123582
# 1426903200         14.672304
