# %%
from CryptoScraper import cryptoDownloader, getAllData
import pandas as pd
from data_utils import BasicFunctions, PriceFunctions, addData
# %load_ext autoreload
# %autoreload 2

# %%
dr = getAllData(cacheOnly=True, how='union')

# %%
coinDf = dr.data()
# Out:
# Getting BTC data
# Getting DASH data
# Getting DOGE data
# Getting ETH data
# Getting LTC data
# Getting STR data
# Getting XMR data
# Getting XRP data

# %%
coinDf['BTC'].head()
# Out:
#          Date      Open     Close       High       Low      Volume
# 0  1364774400  93.25000  93.10000  100.00000  93.03000  345.583889
# 1  1364778000  93.37999  93.10000   93.48797  93.10000   45.243335
# 2  1364781600  93.17000  93.74000   94.00000  93.10999  466.311420
# 3  1364785200  93.80000  92.70002   93.80000  92.49999   96.316180
# 4  1364788800  93.15501  93.15503   93.15503  93.15501    5.000000

# %%
pf = PriceFunctions()

# %%
dataDf = pf.add_yColumns(coinDf)

# %%
dataDf['LTC'].sample(5)
# Out:
#                 Open     Close      High       Low      Volume  \
# Date
# 1462240800  0.008288  0.008263  0.008320  0.008246    0.182851
# 1518717600  0.021960  0.021738  0.021970  0.021576  152.516208
# 1413370800  0.010397  0.010397  0.010397  0.010397    0.011574
# 1515931200  0.017635  0.017620  0.017721  0.017563   68.951225
# 1513152000  0.018159  0.017769  0.018170  0.017700  273.881581
#
#             Percentage Change  Classification
# Date
# 1462240800           0.010007             1.0
# 1518717600           0.048589             1.0
# 1413370800           0.018260             0.0
# 1515931200           0.032399             0.0
# 1513152000           0.011889             1.0

# %%
pd.read_csv('data_utils/trends_data/bitcoin.csv').head() #weekly data from reverse
# Out:
#          date  bitcoin  isPartial
# 0  2018-04-15       14       True
# 1  2018-04-08       16      False
# 2  2018-04-01       17      False
# 3  2018-03-25       18      False
# 4  2018-03-18       18      False

# %%
ad = addData(dataDf)

# %%
dataGo = ad.data_adder('google')
# Out:
# Adding google data for BTC
# Adding google data for DASH
# Adding google data for DOGE
# Adding google data for ETH
# Adding google data for LTC
# Adding google data for STR
# Adding google data for XMR
# Adding google data for XRP

# %%
dataGo['XMR'].sample(5)
# Out:
#                 Open     Close      High       Low      Volume  \
# Date
# 1464822000  0.001710  0.001700  0.001710  0.001698    0.371697
# 1425096000  0.001525  0.001555  0.001561  0.001516    1.509381
# 1493640000  0.017110  0.017381  0.017381  0.017000  172.474012
# 1448661600  0.001065  0.001069  0.001070  0.001058    3.576272
# 1469934000  0.002972  0.002971  0.002972  0.002959    0.845159
#
#             Percentage Change  Classification  Google Trend
# Date
# 1464822000           0.013080             1.0           1.0
# 1425096000           0.060605             1.0           1.0
# 1493640000           0.127924             0.0          80.0
# 1448661600           0.024181             1.0           1.0
# 1469934000           0.020924             0.0           1.0

# %%
pd.read_csv('data_utils/wikipedia_data/pageviews.csv').head()
# Out:
#          Date  bitcoin  litecoin  ethereum  dashpay  dogecoin  stellar  \
# 0  2015-07-01  12957.0     276.0     254.0     82.0    1051.0     21.0
# 1  2015-07-02   9802.0     238.0     222.0     73.0     603.0     28.0
# 2  2015-07-03   8307.0     229.0     245.0     71.0     540.0     25.0
# 3  2015-07-04   8947.0     201.0     275.0     60.0     505.0     15.0
# 4  2015-07-05   8692.0     245.0     207.0     80.0     614.0     11.0
#
#    ripple  monero
# 0   294.0    51.0
# 1   315.0    26.0
# 2   223.0    37.0
# 3   134.0    21.0
# 4   176.0    63.0

# %%
dataWi = ad.data_adder('wikipedia')
# Out:
# Adding wikipedia data for BTC
# Adding wikipedia data for DASH
# Adding wikipedia data for DOGE
# Adding wikipedia data for ETH
# Adding wikipedia data for LTC
# Adding wikipedia data for STR
# Adding wikipedia data for XMR
# Adding wikipedia data for XRP

# %%
dataWi['LTC'].sample(5)
# Out:
#                 Open     Close      High       Low     Volume  \
# Date
# 1456232400  0.008020  0.008020  0.008040  0.007980   1.847267
# 1511107200  0.009091  0.009230  0.009233  0.009085  77.304299
# 1460372400  0.007699  0.007715  0.007715  0.007685   0.375148
# 1452157200  0.007949  0.007950  0.007971  0.007947   0.736915
# 1487559600  0.003608  0.003595  0.003615  0.003595   1.736902
#
#             Percentage Change  Classification  Google Trend  Wikipedia View
# Date
# 1456232400           0.005019             0.0           0.0           238.0
# 1511107200           0.055814             0.0          25.0          3487.0
# 1460372400           0.001599             0.0           0.0           238.0
# 1452157200           0.014031             0.0           0.0           219.0
# 1487559600           0.028634             0.0          25.0          3487.0

# %%
pd.read_csv('data_utils/blockchain_data/pageviews.csv').head()

# %%
blockchainAd = ad.data_adder('blockchain')
# Out:
# Adding blockchain data for BTC

# %%
blockchainAd['BTC'].sample(5)
# Out:
#               Open   Close    High        Low       Volume  Percentage Change  \
# Date
# 1386457200  702.12  693.00  724.00  683.45323  1185.135652           0.117085
# 1436436000  270.48  270.14  272.75  269.97000  1249.367307           0.059499
# 1393830000  569.99  578.00  578.49  565.00000   741.225793           0.138497
# 1427122800  268.01  266.74  268.11  265.43000  1835.444187           0.085986
# 1366556400  124.50  124.50  124.50  124.50000     3.000000           0.016161
#
#             Classification  Google Trend  Wikipedia View    difficulty  \
# Date
# 1386457200             1.0           6.0          9392.0  7.074083e+08
# 1436436000             1.0           2.0          7240.0  4.940201e+10
# 1393830000             1.0           2.0          9392.0  3.815724e+09
# 1427122800             0.0           2.0          7240.0  4.742755e+10
# 1366556400             0.0           6.0          9392.0  8.974296e+06
#
#             cost-per-transaction-percent  cost-per-transaction  \
# Date
# 1386457200                      2.349250             66.265017
# 1436436000                      1.447244              5.049169
# 1393830000                      5.271461             35.412526
# 1427122800                      2.175289              9.551295
# 1366556400                      2.123230              9.472133
#
#             estimated-transaction-volume-usd  estimated-transaction-volume  \
# Date
# 1386457200                      1.087487e+08                 123324.571429
# 1436436000                      5.958344e+07                 203985.714286
# 1393830000                      1.793610e+08                 284634.714286
# 1427122800                      3.809851e+07                 153708.000000
# 1366556400                      2.619604e+07                 187978.285714
#
#                 hash-rate  miners-revenue  n-transactions  output-volume  \
# Date
# 1386457200    6294.616711      3258515.93         49174.0   7.115456e+05
# 1436436000  338898.672582       945214.56        187202.0   1.143858e+06
# 1393830000   28262.418172      2091711.68         59067.0   1.026516e+06
# 1427122800  358360.754760      1015589.19        106330.0   7.358903e+05
# 1366556400      64.686628       454813.92         48016.0   1.295128e+06
#
#             transaction-fees
# Date
# 1386457200         32.372592
# 1436436000         42.450818
# 1393830000         11.100233
# 1427122800         17.375943
# 1366556400         47.639084
