# %%
from CryptoScraper import cryptoDownloader, getAllData
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
dr = getAllData(cacheOnly=True, how='intersect')

# %%
coinDf = dr.data()
# Out:
# Getting BTC data
# Getting DASH data
# Getting DOGE data
# Getting ETH data
# Getting LTC data
# Getting STR data
# Getting XMR data
# Getting XRP data
# 631131300
# 2524587300

# %%
coinDf['BTC']
# Out:
#              Date         Open        Close        High          Low  \
# 0      1364774400    93.250000    93.100000   100.00000    93.030000
# 1      1364778000    93.379990    93.100000    93.48797    93.100000
# 2      1364781600    93.170000    93.740000    94.00000    93.109990
# 3      1364785200    93.800000    92.700020    93.80000    92.499990
# 4      1364788800    93.155010    93.155030    93.15503    93.155010
# 5      1364792400    93.700000    93.790000    93.79000    93.700000
# 6      1364796000    94.067510    94.000010    94.48000    94.000000
# 7      1364799600    94.067510    94.000010    94.48000    94.000000
# 8      1364803200    93.550000    94.000000    94.00000    93.550000
# 9      1364806800    94.229990    94.230000    94.23000    94.229990
# 10     1364810400    94.399860    95.000000    95.00000    94.000000
# 11     1364814000    94.050000    96.000000    96.00000    94.000000
# 12     1364817600    96.675000    98.500000    98.50000    95.982640
# ...
